# %%
# %tensorflow_version 2.x

# %%
from __future__ import absolute_import, division, print_function, unicode_literals


import tensorflow as tf

import pandas as pd

# %%
CSV_COLUMN_NAMES = ['SepalLength', 'SepalWidth', 'PetalLength', 'PetalWidth', 'Species']
SPECIES = ['Setosa', 'Versicolor', 'Virginica']

# %%
train_path = tf.keras.utils.get_file(
    "iris_training.csv", "https://storage.googleapis.com/download.tensorflow.org/data/iris_training.csv")
test_path = tf.keras.utils.get_file(
    "iris_test.csv", "https://storage.googleapis.com/download.tensorflow.org/data/iris_test.csv")

train = pd.read_csv(train_path, names=CSV_COLUMN_NAMES, header=0)
test = pd.read_csv(test_path, names=CSV_COLUMN_NAMES, header=0)
# Out:
# Downloading data from https://storage.googleapis.com/download.tensorflow.org/data/iris_training.csv
# 8192/2194 [================================================================================================================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/download.tensorflow.org/data/iris_test.csv
# 8192/573 [============================================================================================================================================================================================================================================================================================================================================================================================================================================] - 0s 0us/step

# %%
train.head()
# Out:
#    SepalLength  SepalWidth  PetalLength  PetalWidth  Species
# 0          6.4         2.8          5.6         2.2        2
# 1          5.0         2.3          3.3         1.0        1
# 2          4.9         2.5          4.5         1.7        2
# 3          4.9         3.1          1.5         0.1        0
# 4          5.7         3.8          1.7         0.3        0

# %%
train_y = train.pop('Species')
test_y = test.pop('Species')
train.head() # the species column is now gone
# Out:
#    SepalLength  SepalWidth  PetalLength  PetalWidth
# 0          6.4         2.8          5.6         2.2
# 1          5.0         2.3          3.3         1.0
# 2          4.9         2.5          4.5         1.7
# 3          4.9         3.1          1.5         0.1
# 4          5.7         3.8          1.7         0.3

# %%
def input_fn(features, labels, training=True, batch_size=256):
    # Convert the inputs to a Dataset.
    dataset = tf.data.Dataset.from_tensor_slices((dict(features), labels))

    # Shuffle and repeat if you are in training mode.
    if training:
        dataset = dataset.shuffle(1000).repeat()
    
    return dataset.batch(batch_size)

# %%
my_feature_columns = []
for key in train.keys():
    my_feature_columns.append(tf.feature_column.numeric_column(key=key))
print(my_feature_columns)
# Out:
# [NumericColumn(key='SepalLength', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None), NumericColumn(key='SepalWidth', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None), NumericColumn(key='PetalLength', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None), NumericColumn(key='PetalWidth', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None)]

# %%
classifier = tf.estimator.DNNClassifier(
    feature_columns=my_feature_columns,
    # Two hidden layers of 30 and 10 nodes respectively.
    hidden_units=[30, 10],
    # The model must choose between 3 classes.
    n_classes=3)

classifier.train(
    input_fn=lambda: input_fn(train, train_y, training=True),
    steps=5000)
# Out:
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: /tmp/tmprcfyt8mb
# INFO:tensorflow:Using config: {'_model_dir': '/tmp/tmprcfyt8mb', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_experimental_max_worker_delay_secs': None, '_session_creation_timeout_secs': 7200, '_checkpoint_save_graph_def': True, '_service': None, '_cluster_spec': ClusterSpec({}), '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/training/training_util.py:236: Variable.initialized_value (from tensorflow.python.ops.variables) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use Variable.read_value. Variables in 2.X are initialized automatically both in eager and graph (inside tf.defun) contexts.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/optimizer_v2/adagrad.py:83: calling Constant.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 0...
# INFO:tensorflow:Saving checkpoints for 0 into /tmp/tmprcfyt8mb/model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 0...
# INFO:tensorflow:loss = 1.8978328, step = 0
# INFO:tensorflow:global_step/sec: 477.889
# INFO:tensorflow:loss = 1.5173101, step = 100 (0.211 sec)
# INFO:tensorflow:global_step/sec: 672.389
# INFO:tensorflow:loss = 1.4401219, step = 200 (0.149 sec)
# INFO:tensorflow:global_step/sec: 647.224
# INFO:tensorflow:loss = 1.350907, step = 300 (0.154 sec)
# INFO:tensorflow:global_step/sec: 632.017
# INFO:tensorflow:loss = 1.2475806, step = 400 (0.162 sec)
# INFO:tensorflow:global_step/sec: 644.277
# INFO:tensorflow:loss = 1.2453353, step = 500 (0.155 sec)
# INFO:tensorflow:global_step/sec: 627.618
# INFO:tensorflow:loss = 1.2017181, step = 600 (0.159 sec)
# INFO:tensorflow:global_step/sec: 660.356
# INFO:tensorflow:loss = 1.1968393, step = 700 (0.152 sec)
# INFO:tensorflow:global_step/sec: 606.367
# INFO:tensorflow:loss = 1.1619221, step = 800 (0.166 sec)
# INFO:tensorflow:global_step/sec: 606.489
# INFO:tensorflow:loss = 1.127027, step = 900 (0.162 sec)
# INFO:tensorflow:global_step/sec: 649.566
# INFO:tensorflow:loss = 1.1137805, step = 1000 (0.157 sec)
# INFO:tensorflow:global_step/sec: 650.626
# INFO:tensorflow:loss = 1.0697082, step = 1100 (0.154 sec)
# INFO:tensorflow:global_step/sec: 656.327
# INFO:tensorflow:loss = 1.0786202, step = 1200 (0.152 sec)
# INFO:tensorflow:global_step/sec: 649.298
# INFO:tensorflow:loss = 1.0370277, step = 1300 (0.154 sec)
# INFO:tensorflow:global_step/sec: 666.792
# INFO:tensorflow:loss = 1.0283575, step = 1400 (0.152 sec)
# INFO:tensorflow:global_step/sec: 671.431
# INFO:tensorflow:loss = 1.0303932, step = 1500 (0.144 sec)
# INFO:tensorflow:global_step/sec: 611.967
# INFO:tensorflow:loss = 0.9996142, step = 1600 (0.164 sec)
# INFO:tensorflow:global_step/sec: 631.722
# INFO:tensorflow:loss = 1.0010656, step = 1700 (0.158 sec)
# INFO:tensorflow:global_step/sec: 669.136
# INFO:tensorflow:loss = 0.99866384, step = 1800 (0.152 sec)
# INFO:tensorflow:global_step/sec: 661.895
# INFO:tensorflow:loss = 0.97970074, step = 1900 (0.149 sec)
# INFO:tensorflow:global_step/sec: 614.231
# INFO:tensorflow:loss = 0.982123, step = 2000 (0.164 sec)
# INFO:tensorflow:global_step/sec: 657.426
# INFO:tensorflow:loss = 0.96236, step = 2100 (0.149 sec)
# INFO:tensorflow:global_step/sec: 656.601
# INFO:tensorflow:loss = 0.9541479, step = 2200 (0.156 sec)
# INFO:tensorflow:global_step/sec: 644.53
# INFO:tensorflow:loss = 0.9451245, step = 2300 (0.152 sec)
# INFO:tensorflow:global_step/sec: 626.969
# INFO:tensorflow:loss = 0.94409597, step = 2400 (0.159 sec)
# INFO:tensorflow:global_step/sec: 621.534
# INFO:tensorflow:loss = 0.93380773, step = 2500 (0.164 sec)
# INFO:tensorflow:global_step/sec: 641.322
# INFO:tensorflow:loss = 0.92508185, step = 2600 (0.156 sec)
# INFO:tensorflow:global_step/sec: 640.51
# INFO:tensorflow:loss = 0.9234899, step = 2700 (0.155 sec)
# INFO:tensorflow:global_step/sec: 653.031
# INFO:tensorflow:loss = 0.91877604, step = 2800 (0.154 sec)
# INFO:tensorflow:global_step/sec: 649.036
# INFO:tensorflow:loss = 0.91000235, step = 2900 (0.151 sec)
# INFO:tensorflow:global_step/sec: 616.578
# INFO:tensorflow:loss = 0.9015757, step = 3000 (0.165 sec)
# INFO:tensorflow:global_step/sec: 659.763
# INFO:tensorflow:loss = 0.8952991, step = 3100 (0.149 sec)
# INFO:tensorflow:global_step/sec: 645.876
# INFO:tensorflow:loss = 0.89117813, step = 3200 (0.157 sec)
# INFO:tensorflow:global_step/sec: 638.109
# INFO:tensorflow:loss = 0.8851162, step = 3300 (0.155 sec)
# INFO:tensorflow:global_step/sec: 677.498
# INFO:tensorflow:loss = 0.8780638, step = 3400 (0.152 sec)
# INFO:tensorflow:global_step/sec: 588.818
# INFO:tensorflow:loss = 0.8694011, step = 3500 (0.168 sec)
# INFO:tensorflow:global_step/sec: 615.868
# INFO:tensorflow:loss = 0.8683473, step = 3600 (0.160 sec)
# INFO:tensorflow:global_step/sec: 631.411
# INFO:tensorflow:loss = 0.8588337, step = 3700 (0.158 sec)
# INFO:tensorflow:global_step/sec: 640.502
# INFO:tensorflow:loss = 0.8605642, step = 3800 (0.156 sec)
# INFO:tensorflow:global_step/sec: 623.022
# INFO:tensorflow:loss = 0.85421133, step = 3900 (0.161 sec)
# INFO:tensorflow:global_step/sec: 671.977
# INFO:tensorflow:loss = 0.8474208, step = 4000 (0.149 sec)
# INFO:tensorflow:global_step/sec: 660.66
# INFO:tensorflow:loss = 0.84679914, step = 4100 (0.155 sec)
# INFO:tensorflow:global_step/sec: 686.308
# INFO:tensorflow:loss = 0.8413596, step = 4200 (0.143 sec)
# INFO:tensorflow:global_step/sec: 621.896
# INFO:tensorflow:loss = 0.8376087, step = 4300 (0.163 sec)
# INFO:tensorflow:global_step/sec: 665.561
# INFO:tensorflow:loss = 0.8308233, step = 4400 (0.151 sec)
# INFO:tensorflow:global_step/sec: 631.667
# INFO:tensorflow:loss = 0.8314142, step = 4500 (0.158 sec)
# INFO:tensorflow:global_step/sec: 662.854
# INFO:tensorflow:loss = 0.83023524, step = 4600 (0.148 sec)
# INFO:tensorflow:global_step/sec: 663.655
# INFO:tensorflow:loss = 0.8296429, step = 4700 (0.151 sec)
# INFO:tensorflow:global_step/sec: 632.066
# INFO:tensorflow:loss = 0.82106197, step = 4800 (0.162 sec)
# INFO:tensorflow:global_step/sec: 638.082
# INFO:tensorflow:loss = 0.82058567, step = 4900 (0.157 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 5000...
# INFO:tensorflow:Saving checkpoints for 5000 into /tmp/tmprcfyt8mb/model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 5000...
# INFO:tensorflow:Loss for final step: 0.8216937.

# %%
eval_result = classifier.evaluate(
    input_fn=lambda: input_fn(test, test_y, training=False))

print('\nTest set accuracy: {accuracy:0.3f}\n'.format(**eval_result))
# Out:
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2021-05-17T05:12:59Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/tmprcfyt8mb/model.ckpt-5000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Inference Time : 0.24576s
# INFO:tensorflow:Finished evaluation at 2021-05-17-05:12:59
# INFO:tensorflow:Saving dict for global step 5000: accuracy = 0.6, average_loss = 0.8264214, global_step = 5000, loss = 0.8264214
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 5000: /tmp/tmprcfyt8mb/model.ckpt-5000
#
# Test set accuracy: 0.600
